# %%
# ECON662D1 Assignment 3 - Jean-Sébastien Matte 260913682

# %%
# import modules
import numpy as np
import pandas as pd
import scipy as sp
import statsmodels.api as sm
import resample.bootstrap as rb
# np.random.seed(123)

# %%
# load data
in_dir = '/Users/jsmatte/github/ECON662D1/Assignment3'
in_file = str(in_dir + '/e662.as3.20.dat.txt')
df = pd.read_csv(in_file, sep = '\s+', header = None)
print(df)
# Out:
#            0          1          2          3
# 0  -0.429193   91.52508  -7.879150  -22.82027
# 1  -1.719862   58.32108 -10.377350  -46.89894
# 2  -5.007316   71.19264   8.240685  -83.72890
# 3  -0.287603   85.37536  -7.939428  -98.93214
# 4  -5.385808   84.63815  28.309510  -80.68243
# ..       ...        ...        ...        ...
# 95 -4.539189   26.54987 -40.947840 -146.96500
# 96 -9.798897   69.94029  75.729620 -126.41690
# 97 -2.504187   89.50351 -44.335000  -76.11952
# 98 -2.118638  100.67600  48.674720  -16.33207
# 99 -0.782366  133.57730   4.789128  -10.57532
#
# [100 rows x 4 columns]

# %%
df.columns = ['y', 'x1', 'x2', 'x3']
print(df)
# Out:
#            y         x1         x2         x3
# 0  -0.429193   91.52508  -7.879150  -22.82027
# 1  -1.719862   58.32108 -10.377350  -46.89894
# 2  -5.007316   71.19264   8.240685  -83.72890
# 3  -0.287603   85.37536  -7.939428  -98.93214
# 4  -5.385808   84.63815  28.309510  -80.68243
# ..       ...        ...        ...        ...
# 95 -4.539189   26.54987 -40.947840 -146.96500
# 96 -9.798897   69.94029  75.729620 -126.41690
# 97 -2.504187   89.50351 -44.335000  -76.11952
# 98 -2.118638  100.67600  48.674720  -16.33207
# 99 -0.782366  133.57730   4.789128  -10.57532
#
# [100 rows x 4 columns]

# %%
# create matrix X of the regressors (unrestricted model)
X = np.zeros((len(df),4))
for i in range(X.shape[0]):
    X[i] = [1, df.x1.values[i], df.x2.values[i], df.x3.values[i]]
print(X.shape)

# # create matrix X of the regressors (restricted model)
# X_restrict = np.zeros((len(df),3))
# for i in range(X_restrict.shape[0]):
#     X_restrict[i] = [1, df.x2.values[i], df.x3.values[i]]
# print(X.shape)

# create vector y of observations
y = np.array([[j] for j in df.y.values])
print(y.shape)
# Out:
# (100, 4)
# (100, 1)

# %%
# Create the different OLS models of different sample sizes
n = 17
H1 = []
H2 = []
for i in range(n):
    print('MODEL_' + str(i))
    globals()['model_' + str(i)] = sm.OLS(y[0:(20+5*i), :], X[0:(20+5*i), :]).fit()
    temp_reg = globals()['model_' + str(i)]
#     print(temp_reg.summary)
#     print('')
    
    # Residuals
    temp_resid = temp_reg.resid
   
    # Hypothesis 1: H0: B1 = 0
    print('Hopothesis 1: H0: B1 = 0')
    temp_P_H1 = []
    
    # P-value based on Student t-test
    print('P-value based on Student t-test')
    print(temp_reg.t_test('x1 = 0'))
    print(temp_reg.t_test('x1 = 0').pvalue)
    temp_P_H1.append(temp_reg.pvalues[1])
    print('')
    
    
    # P-value from rescaled restricted residuals bootstrap
    temp_nobs = temp_reg.nobs
    
    # rescale residuals
    rescale_factor = np.sqrt(temp_nobs / (temp_nobs - 4))
    temp_resid = temp_reg.resid
    rescaled_temp_resid = rescale_factor * temp_resid
    
    temp_params = temp_reg.params
    B1_list = []
    for b in range(999):
        # draw from distrubances
        draws = np.random.choice(rescaled_temp_resid, size = len(rescaled_temp_resid))  # replace = True, 

        # update observations using rescaled, resampled disturbances
        temp_y_star = temp_reg.fittedvalues + draws
        temp_y_star = np.array([[j] for j in temp_y_star])

        # rerun regression
        temp_reg_star = sm.OLS(temp_y_star, X[0:(20+5*i), :]).fit()

        # get new model B1 parameter
        B1_list.append(temp_reg_star.params[1])
    
    B1_mean = np.mean(B1_list)
    B1_std = np.std(B1_list)
    print('Bootstrap mean for B1: ', B1_mean)
    print('Bootstrap std for B1: ', B1_std)
    boot_t_stat = np.mean(B1_list) / np.std(B1_list)
    boot_pvalue = sp.stats.t.sf(abs(boot_t_stat), temp_nobs - 3)*2
    print('Bootstrap t-statistic for B1: ', boot_t_stat)
    print('Bootstrap p-value for B1: ', boot_pvalue)
#     print('P-value from rescaled restricted residuals bootstrap')
#     print(boot_pvalue)
    temp_P_H1.append(boot_pvalue)
    print('')
    
    
    # P-value from wild bootstrap
    # define the pmf of s* as proposed by Mammen
    xk = [-1, 1]  # -> the rv_discrete class is only defined for xk values that are integers, thus we define the 
                  #    pmf as such. after random draws, we reassign the correct values to the s* vector and carry on
                  #    with our computation
    pk = [((np.sqrt(5)+1) / (2*np.sqrt(5))), ((np.sqrt(5)-1) / (2*np.sqrt(5)))]
    s_pmf = sp.stats.rv_discrete(name = 's_pmf', values = (xk, pk))
    
#     # define the pmf of s* as proposed by Rademacher
#     xk_Rad = [-1, 1]
#     pk_Rad = [0.5, 0.5]
#     s_pmf_Rad = sp.stats.rv_discrete(name = 's_pmf_Rad', values = (xk_Rad, pk_Rad))
    
    # get s_star
    s_star_raw = s_pmf.rvs(size = len(temp_resid))
    
    s_star = []
    for s in s_star_raw:
        if s == -1:
            s_star.append(-(np.sqrt(5) - 1) / 2)
        elif s == 1:
            s_star.append((np.sqrt(5) + 1) / 2)
    
    # update observations using wild disturbances
    temp_y_star_wild = temp_reg.fittedvalues + s_star
    temp_y_star_wild = np.array([[q] for q in temp_y_star_wild])
    
    # rerun regression
    temp_reg_wild = sm.OLS(temp_y_star_wild, X[0:(20+5*i), :]).fit()

    # get new model parameters and regression summary
    temp_param_wild = temp_reg_wild.params
#     print(temp_reg_wild.summary())
    print('P-value from wild bootstrap')
    print(temp_reg_wild.t_test('x1 = 0'))
    print(temp_reg_wild.t_test('x1 = 0').pvalue)
    temp_P_H1.append(temp_reg_wild.t_test('x1 = 0').pvalue)
    print('')
    
    H1.append(temp_P_H1)
    
    
    # Hypothesis 1: H0: B1 = 0.1
    print('Hopothesis 2: H0: B1 = 0.1')
    temp_P_H2 = []
    
    # P-value based on Student t-test
    print('P-value based on Student t-test')
    print(temp_reg.t_test('x1 = 0.1'))
    print(temp_reg.t_test('x1 = 0.1').pvalue)
    temp_P_H2.append(temp_reg.t_test('x1 = 0.1').pvalue)
    print('')
    
    # P-value from rescaled restricted residuals bootstrap
    boot_t_stat2 = (np.mean(B1_list) - 0.1) / np.std(B1_list)
    boot_pvalue2 = sp.stats.t.sf(abs(boot_t_stat2), temp_nobs - 3)*2
    print('Bootstrap t-statistic for B1: ', boot_t_stat2)
    print('Bootstrap p-value for B1: ', boot_pvalue2)
#     print('P-value from rescaled restricted residuals bootstrap')
#     print(boot_pvalue2)
    temp_P_H2.append(boot_pvalue2)
    print('')
    
    
    # P-value from wild bootstrap
    print('P-value from wild bootstrap')
    print(temp_reg_wild.t_test('x1 = 0.1'))
    print(temp_reg_wild.t_test('x1 = 0.1').pvalue)
    temp_P_H2.append(temp_reg_wild.t_test('x1 = 0.1').pvalue)
    print('')
    
    H2.append(temp_P_H2)
    
    print('-------------------------------------------------------')
    print('')
# Out:
# MODEL_0
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0056      0.015      0.366      0.719      -0.027       0.038
# ==============================================================================
# 0.7191648727895874
#
# Bootstrap mean for B1:  0.0055007559184543165
# Bootstrap std for B1:  0.015073020240533471
# Bootstrap t-statistic for B1:  0.3649405249030324
# Bootstrap p-value for B1:  0.7196562586216166
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0125      0.011      1.149      0.267      -0.011       0.036
# ==============================================================================
# 0.26742774874896785
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0056      0.015     -6.202      0.000      -0.027       0.038
# ==============================================================================
# 1.2677103382701062e-05
#
# Bootstrap t-statistic for B1:  -6.269429920051718
# Bootstrap p-value for B1:  8.473641914876963e-06
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0125      0.011     -8.038      0.000      -0.011       0.036
# ==============================================================================
# 5.212902503748504e-07
#
# -------------------------------------------------------
#
# MODEL_1
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0075      0.013      0.571      0.574      -0.020       0.035
# ==============================================================================
# 0.5739307657160999
#
# Bootstrap mean for B1:  0.007483446493442221
# Bootstrap std for B1:  0.012916850820285715
# Bootstrap t-statistic for B1:  0.5793553395917203
# Bootstrap p-value for B1:  0.5682351175115246
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0004      0.011      0.038      0.970      -0.022       0.022
# ==============================================================================
# 0.970062755562171
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0075      0.013     -7.078      0.000      -0.020       0.035
# ==============================================================================
# 5.531466853987899e-07
#
# Bootstrap t-statistic for B1:  -7.1624697686576955
# Bootstrap p-value for B1:  3.517733230071909e-07
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0004      0.011     -9.438      0.000      -0.022       0.022
# ==============================================================================
# 5.277384065238518e-09
#
# -------------------------------------------------------
#
# MODEL_2
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0116      0.013      0.896      0.378      -0.015       0.038
# ==============================================================================
# 0.3783781052307009
#
# Bootstrap mean for B1:  0.011658519715978232
# Bootstrap std for B1:  0.01299393997991378
# Bootstrap t-statistic for B1:  0.8972274563373496
# Bootstrap p-value for B1:  0.3775285842009235
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0218      0.010      2.183      0.038       0.001       0.042
# ==============================================================================
# 0.038283025629155545
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0116      0.013     -6.798      0.000      -0.015       0.038
# ==============================================================================
# 3.2509931250334833e-07
#
# Bootstrap t-statistic for B1:  -6.7986677189968026
# Bootstrap p-value for B1:  2.657788558358801e-07
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0218      0.010     -7.849      0.000       0.001       0.042
# ==============================================================================
# 2.5227570975869075e-08
#
# -------------------------------------------------------
#
# MODEL_3
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0082      0.012      0.711      0.482      -0.015       0.032
# ==============================================================================
# 0.4822052779834689
#
# Bootstrap mean for B1:  0.008898857931439927
# Bootstrap std for B1:  0.011623752218376693
# Bootstrap t-statistic for B1:  0.7655753292272682
# Bootstrap p-value for B1:  0.4495392175322821
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            -0.0045      0.009     -0.484      0.632      -0.023       0.014
# ==============================================================================
# 0.6320781568522751
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0082      0.012     -7.942      0.000      -0.015       0.032
# ==============================================================================
# 5.756860229156435e-09
#
# Bootstrap t-statistic for B1:  -7.837498628414737
# Bootstrap p-value for B1:  6.102193861915522e-09
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            -0.0045      0.009    -11.333      0.000      -0.023       0.014
# ==============================================================================
# 1.487284196761763e-12
#
# -------------------------------------------------------
#
# MODEL_4
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0080      0.010      0.776      0.443      -0.013       0.029
# ==============================================================================
# 0.44263342877850886
# Bootstrap mean for B1:  0.008146454109242975
# Bootstrap std for B1:  0.010828817939543637
# Bootstrap t-statistic for B1:  0.7522939396270147
# Bootstrap p-value for B1:  0.456633837033668
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0172      0.008      2.142      0.039       0.001       0.033
# ==============================================================================
# 0.03900724784307633
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0080      0.010     -8.925      0.000      -0.013       0.029
# ==============================================================================
# 1.181993501685605e-10
#
# Bootstrap t-statistic for B1:  -8.482324331572247
# Bootstrap p-value for B1:  3.330320216736532e-10
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0172      0.008    -10.317      0.000       0.001       0.033
# ==============================================================================
# 2.6821661713045616e-12
#
# -------------------------------------------------------
#
# MODEL_5
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0059      0.009      0.652      0.518      -0.012       0.024
# ==============================================================================
# 0.5183102694510442
#
# Bootstrap mean for B1:  0.0059863455961215095
# Bootstrap std for B1:  0.009172315275292013
# Bootstrap t-statistic for B1:  0.6526537102630203
# Bootstrap p-value for B1:  0.5175361188368375
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0108      0.008      1.372      0.177      -0.005       0.027
# ==============================================================================
# 0.1774832019641933
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0059      0.009    -10.302      0.000      -0.012       0.024
# ==============================================================================
# 6.077865387430382e-13
#
# Bootstrap t-statistic for B1:  -10.249719027553319
# Bootstrap p-value for B1:  5.345006477868729e-13
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0108      0.008    -11.354      0.000      -0.005       0.027
# ==============================================================================
# 3.1067255589495953e-14
#
# -------------------------------------------------------
#
# MODEL_6
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0060      0.008      0.705      0.484      -0.011       0.023
# ==============================================================================
# 0.48410435202344426
#
# Bootstrap mean for B1:  0.006417099878548796
# Bootstrap std for B1:  0.008599480883192671
# Bootstrap t-statistic for B1:  0.7462194480937508
# Bootstrap p-value for B1:  0.45925120750866033
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0099      0.007      1.376      0.176      -0.005       0.024
# ==============================================================================
# 0.17551703949827033
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0060      0.008    -11.118      0.000      -0.011       0.023
# ==============================================================================
# 1.2594535722773976e-14
#
# Bootstrap t-statistic for B1:  -10.882389459619022
# Bootstrap p-value for B1:  1.948918834956709e-14
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0099      0.007    -12.471      0.000      -0.005       0.024
# ==============================================================================
# 2.3217991192208126e-16
#
# -------------------------------------------------------
#
# MODEL_7
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0054      0.008      0.683      0.498      -0.011       0.021
# ==============================================================================
# 0.4979882646508451
#
# Bootstrap mean for B1:  0.005202409422298545
# Bootstrap std for B1:  0.008030977289908047
# Bootstrap t-statistic for B1:  0.6477928195409094
# Bootstrap p-value for B1:  0.5199689932059405
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0155      0.008      2.041      0.046       0.000       0.031
# ==============================================================================
# 0.0464127928630583
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0054      0.008    -11.844      0.000      -0.011       0.021
# ==============================================================================
# 2.9533344279101876e-16
#
# Bootstrap t-statistic for B1:  -11.803991862463214
# Bootstrap p-value for B1:  2.4959877228966905e-16
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0155      0.008    -11.118      0.000       0.000       0.031
# ==============================================================================
# 3.0786887015267994e-15
#
# -------------------------------------------------------
#
# MODEL_8
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0048      0.008      0.619      0.539      -0.011       0.020
# ==============================================================================
# 0.5385403316897768
# Bootstrap mean for B1:  0.004648022249595779
# Bootstrap std for B1:  0.007603046277378083
# Bootstrap t-statistic for B1:  0.6113368352663313
# Bootstrap p-value for B1:  0.5434071410052357
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            -0.0004      0.007     -0.060      0.952      -0.015       0.014
# ==============================================================================
# 0.9520634974457984
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0048      0.008    -12.341      0.000      -0.011       0.020
# ==============================================================================
# 1.3106722086846295e-17
#
# Bootstrap t-statistic for B1:  -12.541285988763763
# Bootstrap p-value for B1:  4.964269349846685e-18
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            -0.0004      0.007    -13.596      0.000      -0.015       0.014
# ==============================================================================
# 2.196207503740029e-19
#
# -------------------------------------------------------
#
# MODEL_9
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0069      0.007      0.995      0.323      -0.007       0.021
# ==============================================================================
# 0.3234446951074834
#
# Bootstrap mean for B1:  0.0071967033070869145
# Bootstrap std for B1:  0.007058699620549591
# Bootstrap t-statistic for B1:  1.0195508654505656
# Bootstrap p-value for B1:  0.3119035245009839
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            -0.0010      0.007     -0.144      0.886      -0.014       0.012
# ==============================================================================
# 0.8859941960175052
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0069      0.007    -13.376      0.000      -0.007       0.021
# ==============================================================================
# 8.516662136777213e-20
#
# Bootstrap t-statistic for B1:  -13.147364483783972
# Bootstrap p-value for B1:  1.3727850153977828e-19
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            -0.0010      0.007    -14.995      0.000      -0.014       0.012
# ==============================================================================
# 3.959102594913527e-22
#
# -------------------------------------------------------
#
# MODEL_10
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0065      0.007      0.977      0.332      -0.007       0.020
# ==============================================================================
# 0.33229488641697214
#
# Bootstrap mean for B1:  0.006357073093580523
# Bootstrap std for B1:  0.0065324723658491905
# Bootstrap t-statistic for B1:  0.9731496342509416
# Bootstrap p-value for B1:  0.3339793149461556
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0022      0.006      0.338      0.736      -0.011       0.015
# ==============================================================================
# 0.7363192557269659
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0065      0.007    -14.031      0.000      -0.007       0.020
# ==============================================================================
# 1.759903376625857e-21
#
# Bootstrap t-statistic for B1:  -14.334990132674882
# Bootstrap p-value for B1:  4.322057477549942e-22
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0022      0.006    -15.236      0.000      -0.011       0.015
# ==============================================================================
# 2.710516200217761e-23
#
# -------------------------------------------------------
#
# MODEL_11
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0058      0.006      0.911      0.366      -0.007       0.018
# ==============================================================================
# 0.36556678284711674
#
# Bootstrap mean for B1:  0.0059569648907735915
# Bootstrap std for B1:  0.006541894405060488
# Bootstrap t-statistic for B1:  0.9105871360695728
# Bootstrap p-value for B1:  0.36555142761470183
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0047      0.006      0.732      0.467      -0.008       0.017
# ==============================================================================
# 0.4665227782932383
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0058      0.006    -14.826      0.000      -0.007       0.018
# ==============================================================================
# 1.971310389497955e-23
#
# Bootstrap t-statistic for B1:  -14.37550490519678
# Bootstrap p-value for B1:  7.519865716497828e-23
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0047      0.006    -14.845      0.000      -0.008       0.017
# ==============================================================================
# 1.8385454456457176e-23
#
# -------------------------------------------------------
#
# MODEL_12
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0056      0.006      0.939      0.351      -0.006       0.018
# ==============================================================================
# 0.3507738743613309
# Bootstrap mean for B1:  0.005683961046845259
# Bootstrap std for B1:  0.005844084743496984
# Bootstrap t-statistic for B1:  0.972600723008012
# Bootstrap p-value for B1:  0.33379726699626067
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0053      0.006      0.884      0.380      -0.007       0.017
# ==============================================================================
# 0.37960673834330305
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0056      0.006    -15.794      0.000      -0.006       0.018
# ==============================================================================
# 1.0293753404586424e-25
#
# Bootstrap t-statistic for B1:  -16.138718566342675
# Bootstrap p-value for B1:  2.019931261811427e-26
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0053      0.006    -15.845      0.000      -0.007       0.017
# ==============================================================================
# 8.534370373825494e-26
#
# -------------------------------------------------------
#
# MODEL_13
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0074      0.006      1.240      0.218      -0.004       0.019
# ==============================================================================
# 0.2183931603692
#
# Bootstrap mean for B1:  0.007453953004851092
# Bootstrap std for B1:  0.005980514380770255
# Bootstrap t-statistic for B1:  1.2463732264934486
# Bootstrap p-value for B1:  0.2161762884640856
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0049      0.006      0.815      0.417      -0.007       0.017
# ==============================================================================
# 0.41731108796753635
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0074      0.006    -15.633      0.000      -0.004       0.019
# ==============================================================================
# 3.525509240987683e-26
#
# Bootstrap t-statistic for B1:  -15.474596515096003
# Bootstrap p-value for B1:  4.785108026468087e-26
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0049      0.006    -15.826      0.000      -0.007       0.017
# ==============================================================================
# 1.666240266199749e-26
#
# -------------------------------------------------------
#
# MODEL_14
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0060      0.006      1.068      0.288      -0.005       0.017
# ==============================================================================
# 0.2883284369379734
#
# Bootstrap mean for B1:  0.006185614173998414
# Bootstrap std for B1:  0.005493353260334939
# Bootstrap t-statistic for B1:  1.1260179130772425
# Bootstrap p-value for B1:  0.26325448120680056
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            -0.0005      0.006     -0.086      0.932      -0.012       0.011
# ==============================================================================
# 0.9316448652266193
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0060      0.006    -16.847      0.000      -0.005       0.017
# ==============================================================================
# 5.614180234741586e-29
#
# Bootstrap t-statistic for B1:  -17.07779954793615
# Bootstrap p-value for B1:  1.5916617390736073e-29
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0            -0.0005      0.006    -17.347      0.000      -0.012       0.011
# ==============================================================================
# 7.978610341114582e-30
#
# -------------------------------------------------------
#
# MODEL_15
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0078      0.005      1.487      0.140      -0.003       0.018
# ==============================================================================
# 0.14044919427501004
#
# Bootstrap mean for B1:  0.008079677006645023
# Bootstrap std for B1:  0.005387934588758282
# Bootstrap t-statistic for B1:  1.499587063195414
# Bootstrap p-value for B1:  0.1371452865887864
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0134      0.005      2.457      0.016       0.003       0.024
# ==============================================================================
# 0.015921565870750404
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0078      0.005    -17.522      0.000      -0.003       0.018
# ==============================================================================
# 6.554912441072832e-31
#
# Bootstrap t-statistic for B1:  -17.060400693271813
# Bootstrap p-value for B1:  3.0280943098551796e-30
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0134      0.005    -15.891      0.000       0.003       0.024
# ==============================================================================
# 5.448440657582025e-28
#
# -------------------------------------------------------
#
# MODEL_16
# Hopothesis 1: H0: B1 = 0
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0063      0.005      1.228      0.222      -0.004       0.016
# ==============================================================================
# 0.22242857874816382
# Bootstrap mean for B1:  0.0064839158590998145
# Bootstrap std for B1:  0.00517881009096212
# Bootstrap t-statistic for B1:  1.25200880998037
# Bootstrap p-value for B1:  0.21357720392125012
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0135      0.005      2.529      0.013       0.003       0.024
# ==============================================================================
# 0.013081016515601389
#
# Hopothesis 2: H0: B1 = 0.1
# P-value based on Student t-test
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0063      0.005    -18.404      0.000      -0.004       0.016
# ==============================================================================
# 3.0020740148204965e-33
#
# Bootstrap t-statistic for B1:  -18.057446111820404
# Bootstrap p-value for B1:  8.710800104080166e-33
#
# P-value from wild bootstrap
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0135      0.005    -16.268      0.000       0.003       0.024
# ==============================================================================
# 2.4186614653392984e-29
#
# -------------------------------------------------------

# %%
print(H1)
print('')
print(H2)
# Out:
# [[0.7191648727895876, 0.7196562586216166, array(0.26742775)], [0.5739307657161, 0.5682351175115246, array(0.97006276)], [0.3783781052307009, 0.3775285842009235, array(0.03828303)], [0.4822052779834689, 0.4495392175322821, array(0.63207816)], [0.44263342877850886, 0.456633837033668, array(0.03900725)], [0.5183102694510442, 0.5175361188368375, array(0.1774832)], [0.48410435202344426, 0.45925120750866033, array(0.17551704)], [0.4979882646508451, 0.5199689932059405, array(0.04641279)], [0.5385403316897768, 0.5434071410052357, array(0.9520635)], [0.3234446951074834, 0.3119035245009839, array(0.8859942)], [0.33229488641697214, 0.3339793149461556, array(0.73631926)], [0.36556678284711674, 0.36555142761470183, array(0.46652278)], [0.3507738743613309, 0.33379726699626067, array(0.37960674)], [0.21839316036920003, 0.2161762884640856, array(0.41731109)], [0.2883284369379734, 0.26325448120680056, array(0.93164487)], [0.14044919427501004, 0.1371452865887864, array(0.01592157)], [0.22242857874816382, 0.21357720392125012, array(0.01308102)]]
#
# [[array(1.26771034e-05), 8.473641914876963e-06, array(5.2129025e-07)], [array(5.53146685e-07), 3.517733230071909e-07, array(5.27738407e-09)], [array(3.25099313e-07), 2.657788558358801e-07, array(2.5227571e-08)], [array(5.75686023e-09), 6.102193861915522e-09, array(1.4872842e-12)], [array(1.1819935e-10), 3.330320216736532e-10, array(2.68216617e-12)], [array(6.07786539e-13), 5.345006477868729e-13, array(3.10672556e-14)], [array(1.25945357e-14), 1.948918834956709e-14, array(2.32179912e-16)], [array(2.95333443e-16), 2.4959877228966905e-16, array(3.0786887e-15)], [array(1.31067221e-17), 4.964269349846685e-18, array(2.1962075e-19)], [array(8.51666214e-20), 1.3727850153977828e-19, array(3.95910259e-22)], [array(1.75990338e-21), 4.322057477549942e-22, array(2.7105162e-23)], [array(1.97131039e-23), 7.519865716497828e-23, array(1.83854545e-23)], [array(1.02937534e-25), 2.019931261811427e-26, array(8.53437037e-26)], [array(3.52550924e-26), 4.785108026468087e-26, array(1.66624027e-26)], [array(5.61418023e-29), 1.5916617390736073e-29, array(7.97861034e-30)], [array(6.55491244e-31), 3.0280943098551796e-30, array(5.44844066e-28)], [array(3.00207401e-33), 8.710800104080166e-33, array(2.41866147e-29)]]

# %%
H11 = []
H12 = []
H13 = []
for H in H1:
    H11.append(H[0])
    H12.append(H[1])
    H13.append(H[2])
    
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(H11)
plt.plot(H12)
plt.plot(H13)
plt.show()

# %%
resid_16 = model_16.resid
x = np.arange(len(resid_16))
import matplotlib.pyplot as plt
# %matplotlib inline
# plt.scatter(x, resid_16)
plt.plot(resid_16)
plt.show()

# %%
print(model_0.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     6.351
# Date:                Wed, 25 Nov 2020   Prob (F-statistic):            0.00485
# Time:                        15:05:14   Log-Likelihood:                -34.074
# No. Observations:                  20   AIC:                             76.15
# Df Residuals:                      16   BIC:                             80.13
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6174      1.558     -0.396      0.697      -3.920       2.685
# x1             0.0056      0.015      0.366      0.719      -0.027       0.038
# x2            -0.0424      0.012     -3.534      0.003      -0.068      -0.017
# x3             0.0332      0.013      2.478      0.025       0.005       0.062
# ==============================================================================
# Omnibus:                        3.991   Durbin-Watson:                   2.331
# Prob(Omnibus):                  0.136   Jarque-Bera (JB):                2.583
# Skew:                           0.878   Prob(JB):                        0.275
# Kurtosis:                       3.138   Cond. No.                         479.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Test --- Test --- Test --- Test --- Test --- Test --- Test --- Test
for i1 in [0]:
    print(globals()['model_' + str(i1)].summary())
    print('')
#     print(globals()['model_' + str(i1)].pvalues)
#     print('')
    
    # Hypothesis 1: H0: B1 = 0
    # P-value based on Student t-test
    print(globals()['model_' + str(i1)].t_test('x1 = 0'))
    print(globals()['model_' + str(i1)].t_test('x1 = 0.1'))
    print('')
#     print(globals()['model_' + str(i1)].t_test('x1 = 0').pvalue)
#     print('')

    # P-value from rescaled restricted residuals bootstrap
    temp_nobs = globals()['model_' + str(i1)].nobs
    rescale_factor = np.sqrt(temp_nobs / (temp_nobs - 4))
    
    
    temp_params = globals()['model_' + str(i1)].params
    temp_resid = globals()['model_' + str(i1)].resid
    reg_star = globals()['model_' + str(i1)]
    B1_list = []
    for b in range(999):
        # rescale residuals
        rescaled_temp_resid = rescale_factor * temp_resid
        
        # draw from distrubances
        draw = np.random.choice(rescaled_temp_resid, size = len(rescaled_temp_resid))  # replace = True, 

        # update observations using rescaled, resampled disturbances
        temp_y_star = np.matmul(X[0:(20+5*i1), :], temp_params.T) + draw
#         temp_y_star_test = reg_star.fittedvalues + draw
        temp_y_star = np.array([[j] for j in temp_y_star])

        # rerun regression
        temp_reg = sm.OLS(temp_y_star, X[0:(20+5*i1), :]).fit()

        # get new model parameters and residuals
        B1_list.append(temp_reg.params[1])
#         temp_param = temp_reg.params
#         temp_resid = temp_reg.resid
#         reg_star = temp_reg
        
#     print(reg_star.summary())
#     print(reg_star.t_test('x1 = 0'))
#     print(reg_star.t_test('x1 = 0.1'))
    B1_mean = np.mean(B1_list)
    B1_std = np.std(B1_list)
    print(B1_mean, B1_std)
    boot_t_stat = np.mean(B1_list) / np.std(B1_list)
    boot_pvalue = sp.stats.t.sf(boot_t_stat, temp_nobs - 3)*2
    print(boot_t_stat)
    print(boot_pvalue)
#     boot_stat1, boot_pvalue1 = sp.stats.ttest_1samp(B1_list, 0)
#     print(boot_stat1, boot_pvalue1)
    print('')
    
    # P-value from wild bootstrap
    temp_resid_wild = globals()['model_' + str(i1)].resid
    
    # define the pmf of s*
    xk = [-1, 1]  # -> the rv_discrete class is only defined for xk values that are integers, thus we define the 
                  #    pmf as such. after random draws, we reassign the correct values to the s* vector and carry on
                  #    with our computation
    pk = [((np.sqrt(5)+1) / (2*np.sqrt(5))), ((np.sqrt(5)-1) / (2*np.sqrt(5)))]
    s_pmf = sp.stats.rv_discrete(name = 's_pmf', values = (xk, pk))
    
#     import matplotlib.pyplot as plt
#     %matplotlib inline
#     fig, ax = plt.subplots(1, 1)
#     ax.plot(xk, s_pmf.pmf(xk), 'ro', ms=12, mec='r')
#     ax.vlines(xk, 0, s_pmf.pmf(xk), colors='r', lw=4)
#     plt.show()
    
    # get s_star
    s_star_raw = s_pmf.rvs(size = len(temp_resid_wild))
#     print(s_star_raw)
    
    s_star = []
    for s in s_star_raw:
        if s == -1:
            s_star.append(-(np.sqrt(5) - 1) / 2)
        elif s == 1:
            s_star.append((np.sqrt(5) + 1) / 2)
#     print(s_star)
    
    # update observations using wild disturbances
    temp_y_star_wild = np.matmul(X[0:(20+5*i1), :], temp_params.T) + s_star
    temp_y_star_wild = np.array([[j] for j in temp_y_star_wild])
    
    # rerun regression
    temp_reg_wild = sm.OLS(temp_y_star_wild, X[0:(20+5*i1), :]).fit()

    # get new model parameters and regression summary
    temp_param_wild = temp_reg_wild.params
    print(temp_reg_wild.summary())
    print(temp_reg_wild.t_test('x1 = 0'))
    print(temp_reg_wild.t_test('x1 = 0.1'))

    

    
    
    
    # Hypothesis 2: H0: B1 = 0.1
#     print(globals()['model_' + str(i1)].t_test('x1 = 0.1'))
#     print('')
#     print(globals()['model_' + str(i1)].t_test('x1 = 0.1').pvalue)
#     print('')
    
    print('-----------------------------------')
    print('')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     6.351
# Date:                Thu, 26 Nov 2020   Prob (F-statistic):            0.00485
# Time:                        12:27:37   Log-Likelihood:                -34.074
# No. Observations:                  20   AIC:                             76.15
# Df Residuals:                      16   BIC:                             80.13
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6174      1.558     -0.396      0.697      -3.920       2.685
# x1             0.0056      0.015      0.366      0.719      -0.027       0.038
# x2            -0.0424      0.012     -3.534      0.003      -0.068      -0.017
# x3             0.0332      0.013      2.478      0.025       0.005       0.062
# ==============================================================================
# Omnibus:                        3.991   Durbin-Watson:                   2.331
# Prob(Omnibus):                  0.136   Jarque-Bera (JB):                2.583
# Skew:                           0.878   Prob(JB):                        0.275
# Kurtosis:                       3.138   Cond. No.                         479.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0056      0.015      0.366      0.719      -0.027       0.038
# ==============================================================================
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0056      0.015     -6.202      0.000      -0.027       0.038
# ==============================================================================
#
# 0.005682486329868616 0.015444097771524338
# 0.36793902848413224
# 0.717459868607966
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.598
# Model:                            OLS   Adj. R-squared:                  0.523
# Method:                 Least Squares   F-statistic:                     7.939
# Date:                Thu, 26 Nov 2020   Prob (F-statistic):            0.00182
# Time:                        12:27:37   Log-Likelihood:                -29.228
# No. Observations:                  20   AIC:                             66.46
# Df Residuals:                      16   BIC:                             70.44
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6977      1.223     -0.571      0.576      -3.289       1.894
# x1             0.0028      0.012      0.236      0.816      -0.023       0.028
# x2            -0.0395      0.009     -4.195      0.001      -0.059      -0.020
# x3             0.0255      0.011      2.428      0.027       0.003       0.048
# ==============================================================================
# Omnibus:                        8.386   Durbin-Watson:                   2.773
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):                2.983
# Skew:                           0.614   Prob(JB):                        0.225
# Kurtosis:                       1.561   Cond. No.                         479.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0028      0.012      0.236      0.816      -0.023       0.028
# ==============================================================================
#                              Test for Constraints
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# c0             0.0028      0.012     -8.132      0.000      -0.023       0.028
# ==============================================================================
# -----------------------------------
